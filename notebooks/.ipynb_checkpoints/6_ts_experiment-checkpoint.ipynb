# %%
library( forecast )
# Out:
# Warning message:
# “package ‘forecast’ was built under R version 3.4.4”

# %%
plot.ts( nottem )
# Out:
# plot without title

# %%
tsdisplay( nottem )
# Out:
# Plot with title “”

# %%
plot( stl( nottem, 'periodic' ))
# Out:
# plot without title

# %%
ets( nottem, model = 'ANA')
# Out:
# ETS(A,N,A)
#
# Call:
#  ets(y = nottem, model = "ANA")
#
#   Smoothing parameters:
#     alpha = 0.0392
#     gamma = 1e-04
#
#   Initial states:
#     l = 49.4597
#     s=-9.5635 -6.6186 0.5447 7.4811 11.5783 12.8567
#            8.9762 3.4198 -2.7516 -6.8093 -9.7583 -9.3556
#
#   sigma:  2.3203
#
#      AIC     AICc      BIC
# 1734.944 1737.087 1787.154

# %%
plot( ets( nottem, model = 'ANA') )
# Out:
# plot without title

# %%
plot( forecast( ets( nottem, model = 'ANA' ) ) )
# Out:
# Plot with title “Forecasts from ETS(A,N,A)”
