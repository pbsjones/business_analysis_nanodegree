# %%
library( readxl )
library( caret )
library( lubridate )
library( ggmap )

# %%
df <- read_excel( '../data/7_segmentation/scaling-exercise-data.xlsx' )

# %%
df
# Out:
#   Store ID % Income > 50K # of Households
# 1 1        0.35            50000
# 2 2        0.40           100000
# 3 3        0.70            25000
# 4 4        0.10           400000
# 5 5        0.90           250000

# %%
scale( df$"% Income > 50K")
# Out:
#      [,1]
# [1,] -0.4472136
# [2,] -0.2874945
# [3,]  0.6708204
# [4,] -1.2458093
# [5,]  1.3096970

# %%
scale( df$"# of Households")
# Out:
#      [,1]
# [1,] -0.7291490
# [2,] -0.4121277
# [3,] -0.8876597
# [4,]  1.4900002
# [5,]  0.5389362

# %%
df <- read.csv( '../data//7_segmentation/climate-data-sample.csv' )

# %%
head( df )
# Out:
#   StoreID City         State Date.Last.Winter.Freeze Date.First.Winter.Freeze
# 1  2      Hayward      WI    2009-06-25              2009-08-31
# 2  3      Baxter       MN    2009-05-29              2009-09-06
# 3  6      Grand Rapids MN    2009-06-02              2009-09-11
# 4  9      Bottineau    ND    2009-05-31              2009-09-16
# 5 10      Bemidji      MN    2009-05-31              2009-09-20
# 6 11      Wadena       MN    2009-05-24              2009-09-21
#   Growing.Season.Length Jan.Avg.Tot.Prec Feb.Avg.Tot.Prec Mar.Avg.Tot.Prec
# 1 126                   0.532            0.808            1.636
# 2 147                   0.352            0.464            1.690
# 3 133                   0.370            0.098            1.250
# 4 141                   0.256            0.280            0.702
# 5 147                   0.176            0.154            1.318
# 6 151                   0.246            0.456            1.790
#   Apr.Avg.Tot.Prec ⋯ Jun.Avg.Temp Jul.Avg.Temp Aug.Avg.Temp Sep.Avg.Temp
# 1 2.368            ⋯ 63.06        68.08        65.75        56.12
# 2 1.712            ⋯ 64.00        68.61        66.23        55.88
# 3 1.148            ⋯ 62.86        67.32        65.19        55.11
# 4 0.896            ⋯ 62.58        66.84        65.51        54.34
# 5 1.278            ⋯ 62.89        67.45        65.30        55.14
# 6 1.548            ⋯ 64.37        68.74        66.90        56.83
#   Oct.Avg.Temp Nov.Avg.Temp Dec.Avg.Temp Elevation Longitude  Latitude
# 1 44.82        29.59        15.40        1271.08    -91.27598 46.03058
# 2 43.90        27.58        12.46        1221.80    -94.28250 46.34109
# 3 43.54        26.76        11.44        1329.16    -93.53763 47.19999
# 4 41.55        23.39         8.71        1696.13   -100.39696 48.85540
# 5 43.60        25.94        11.15        1394.71    -94.81920 47.51467
# 6 44.70        27.40        12.65        1384.48    -95.14531 46.46750

# %%
df <- transform( df
               , Date.Last.Winter.Freeze = ymd( Date.Last.Winter.Freeze )
               , Date.First.Winter.Freeze = ymd( Date.First.Winter.Freeze)
               )

# %%
df$Date.Last.Winter.Freeze <- df$Date.Last.Winter.Freeze - median( df$Date.Last.Winter.Freeze )

# %%
df$Date.First.Winter.Freeze <- df$Date.First.Winter.Freeze - median( df$Date.First.Winter.Freeze )

# %%
head( df )
# Out:
#   StoreID City         State Date.Last.Winter.Freeze Date.First.Winter.Freeze
# 1  2      Hayward      WI    56 days                 -42 days
# 2  3      Baxter       MN    29 days                 -36 days
# 3  6      Grand Rapids MN    33 days                 -31 days
# 4  9      Bottineau    ND    31 days                 -26 days
# 5 10      Bemidji      MN    31 days                 -22 days
# 6 11      Wadena       MN    24 days                 -21 days
#   Growing.Season.Length Jan.Avg.Tot.Prec Feb.Avg.Tot.Prec Mar.Avg.Tot.Prec
# 1 126                   0.532            0.808            1.636
# 2 147                   0.352            0.464            1.690
# 3 133                   0.370            0.098            1.250
# 4 141                   0.256            0.280            0.702
# 5 147                   0.176            0.154            1.318
# 6 151                   0.246            0.456            1.790
#   Apr.Avg.Tot.Prec ⋯ Jun.Avg.Temp Jul.Avg.Temp Aug.Avg.Temp Sep.Avg.Temp
# 1 2.368            ⋯ 63.06        68.08        65.75        56.12
# 2 1.712            ⋯ 64.00        68.61        66.23        55.88
# 3 1.148            ⋯ 62.86        67.32        65.19        55.11
# 4 0.896            ⋯ 62.58        66.84        65.51        54.34
# 5 1.278            ⋯ 62.89        67.45        65.30        55.14
# 6 1.548            ⋯ 64.37        68.74        66.90        56.83
#   Oct.Avg.Temp Nov.Avg.Temp Dec.Avg.Temp Elevation Longitude  Latitude
# 1 44.82        29.59        15.40        1271.08    -91.27598 46.03058
# 2 43.90        27.58        12.46        1221.80    -94.28250 46.34109
# 3 43.54        26.76        11.44        1329.16    -93.53763 47.19999
# 4 41.55        23.39         8.71        1696.13   -100.39696 48.85540
# 5 43.60        25.94        11.15        1394.71    -94.81920 47.51467
# 6 44.70        27.40        12.65        1384.48    -95.14531 46.46750

# %%
qmplot( Longitude
       , Latitude
       , size = Jun.Avg.Snow
       , alpha = 0.1
       , data = df
       , maptype = "toner-lite"
       , color = I("red") )
# Out:
# Using zoom = 4...
# Warning message:
# “`panel.margin` is deprecated. Please use `panel.spacing` property instead”
# plot without title
