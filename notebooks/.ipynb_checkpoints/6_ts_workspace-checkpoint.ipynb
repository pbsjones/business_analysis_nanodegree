# %%
library(readxl)
library( forecast )
library( lubridate )
# Out:
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date

# %%
df <- read_excel( '../data/6_ts/tb-sales.xlsx')

# %%
head( df )
# Out:
#   DATE       Toothbrush Sales
# 1 2009-01-01 7523.622
# 2 2009-02-01 7551.028
# 3 2009-03-01 7543.573
# 4 2009-04-01 7551.169
# 5 2009-05-01 7562.281
# 6 2009-06-01 7625.045

# %%
df$sales <- as.double( df$"Toothbrush Sales")
df$DATE <- ymd( df$DATE )

# %%
df <- df[,c(1,3)]

# %%
summary( df )
# Out:
#       DATE                sales
#  Min.   :2009-01-01   Min.   :7524
#  1st Qu.:2010-11-08   1st Qu.:7803
#  Median :2012-09-16   Median :8205
#  Mean   :2012-09-15   Mean   :8109
#  3rd Qu.:2014-07-24   3rd Qu.:8392
#  Max.   :2016-06-01   Max.   :8517

# %%
df.ts <- ts(df, start=c(2009, 1), end=c(2016, 6), frequency=12)

# %%
ndiffs( df.ts )
# Out:
# [1] 1

# %%
diff( df.ts, 1)
# Out:
#       DATE sales
#  [1,] 31   27.4060
#  [2,] 28   -7.4550
#  [3,] 31    7.5970
#  [4,] 30   11.1115
#  [5,] 31   62.7640
#  [6,] 30   -2.2720
#  [7,] 31   25.5245
#  [8,] 31   14.7680
#  [9,] 30   23.0040
# [10,] 31   25.7375
# [11,] 30    4.0115
# [12,] 31    5.0055
# [13,] 31   -7.3485
# [14,] 28    2.5560
# [15,] 31    1.7750
# [16,] 30   -4.0115
# [17,] 31   -3.2305
# [18,] 30   14.4130
# [19,] 31   11.2890
# [20,] 31   12.4960
# [21,] 30   26.9800
# [22,] 31   19.7025
# [23,] 30   31.3110
# [24,] 31   25.3825
# [25,] 31   25.2405
# [26,] 28   40.7540
# [27,] 31   37.1685
# [28,] 30   25.3115
# [29,] 31    0.0000
# [30,] 30   20.9095
# [31,] ⋮    ⋮
# [32,] 31    20.9095
# [33,] 31     6.5675
# [34,] 28     9.7980
# [35,] 31    21.2290
# [36,] 30    10.9340
# [37,] 31     7.5615
# [38,] 30     8.6265
# [39,] 31    -3.4080
# [40,] 31    12.3185
# [41,] 30     5.0055
# [42,] 31   -13.8450
# [43,] 30   -28.2935
# [44,] 31   -53.6050
# [45,] 31    16.3655
# [46,] 28    15.7620
# ...

# %%
plot( df.ts )
# Out:
# plot without title

# %%
fit.hw <- HoltWinters(df.ts)

# %%
plot( fit.hw )
# Out:
# Error in xy.coords(x, y): 'x' and 'y' lengths differ
# Traceback:
#
# 1. plot(fit.hw)
# 2. plot.HoltWinters(fit.hw)
# 3. lines(x$x, col = col, lty = lty)
# 4. lines.ts(x$x, col = col, lty = lty)
# 5. lines.default(time(as.ts(x)), x, ...)
# 6. plot.xy(xy.coords(x, y), type = type, ...)
# 7. xy.coords(x, y)
# 8. stop("'x' and 'y' lengths differ")
# Plot with title “Holt-Winters filtering”

# %%
pacf( df.ts )
# Out:
# Plot with title “sales”
