# %% [markdown]
# ### Libraries

# %%
library( tidyverse )
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.3.4     ✔ dplyr   0.7.4
# ✔ tidyr   0.7.2     ✔ stringr 1.2.0
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ### Data

# %%
df.aa <- read.csv( '../data/raw/districta-attendance.csv' )
df.af <- read.csv( '../data/raw/districta-finance.csv' )
df.ba <- read.csv( '../data/raw/districtb-attendance.csv' )
df.bf <- read.csv( '../data/raw/districtb-finance.csv' )

# %%
head( df.aa )
# Out:
#   School   Average.daily.Attendance Percent.Attendance Pupil.Teacher.ratio X
# 1 Adair     451.4                   90.77              33.8                NA
# 2 Crew      440.6                   89.32              36.3                NA
# 3 Davis     139.4                   86.51              22.6                NA
# 4 Faith     427.3                   91.12              30.0                NA
# 5 Formwalt  706.1                   89.46              32.5                NA
# 6 Forrest  4312.0                   89.72              36.0                NA
#   X.1
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
head( df.af )
# Out:
#   School   Value  Metric
# 1 Adair     66.90 Per-Pupil Cost
# 2 Crew      61.08 Per-Pupil Cost
# 3 Davis    105.21 Per-Pupil Cost
# 4 Faith     75.35 Per-Pupil Cost
# 5 Formwalt  59.45 Per-Pupil Cost
# 6 Forrest   59.03 Per-Pupil Cost

# %%
df.a <- left_join( df.aa, df.af )
# Out:
# Joining, by = "School"
# Warning message:
# “Column `School` joining factors with different levels, coercing to character vector”

# %%
head( df.a )
# Out:
#   School Average.daily.Attendance Percent.Attendance Pupil.Teacher.ratio X  X.1
# 1 Adair  451.4                    90.77              33.8                NA NA
# 2 Adair  451.4                    90.77              33.8                NA NA
# 3 Crew   440.6                    89.32              36.3                NA NA
# 4 Crew   440.6                    89.32              36.3                NA NA
# 5 Davis  139.4                    86.51              22.6                NA NA
# 6 Davis  139.4                    86.51              22.6                NA NA
#   Value  Metric
# 1  66.90 Per-Pupil Cost
# 2 160.22 Average Monthly Teacher Salary
# 3  61.08 Per-Pupil Cost
# 4 146.24 Average Monthly Teacher Salary
# 5 105.21 Per-Pupil Cost
# 6 159.79 Average Monthly Teacher Salary

# %%
df.a <- df.a %>%
    spread( Metric, Value )

# %%
head( df.a )
# Out:
#   School   Average.daily.Attendance Percent.Attendance Pupil.Teacher.ratio X
# 1 Adair     451.4                   90.77              33.8                NA
# 2 Crew      440.6                   89.32              36.3                NA
# 3 Davis     139.4                   86.51              22.6                NA
# 4 Faith     427.3                   91.12              30.0                NA
# 5 Formwalt  706.1                   89.46              32.5                NA
# 6 Forrest  4312.0                   89.72              36.0                NA
#   X.1 Average Monthly Teacher Salary Per-Pupil Cost <NA>
# 1 NA  160.22                          66.90         NA
# 2 NA  146.24                          61.08         NA
# 3 NA  159.79                         105.21         NA
# 4 NA  152.39                          75.35         NA
# 5 NA  139.11                          59.45         NA
# 6 NA  154.99                          59.03         NA

# %%
names( df.a ) <- c( 'school_nm'
                   , 'attendance_daily_average_no'
                   , 'attendance_percent_no'
                   , 'pupil_teacher_ratio'
                  , 'X'
                  , 'X1'
                  , 'teacher_monthly_avg_salary_no'
                  , 'per_pupil_cost'
                  , 'X2' )

# %%
df.a <- df.a %>%
    select( school_nm
           , attendance_daily_average_no
           , attendance_percent_no 
           , pupil_teacher_ratio
           , teacher_monthly_avg_salary_no
          , per_pupil_cost )

# %%
df.a$district_cd <- 'a'

# %%
head( df.a )
# Out:
#   school_nm attendance_daily_average_no attendance_percent_no
# 1 Adair      451.4                      90.77
# 2 Crew       440.6                      89.32
# 3 Davis      139.4                      86.51
# 4 Faith      427.3                      91.12
# 5 Formwalt   706.1                      89.46
# 6 Forrest   4312.0                      89.72
#   pupil_teacher_ratio teacher_monthly_avg_salary_no per_pupil_cost district_cd
# 1 33.8                160.22                         66.90         a
# 2 36.3                146.24                         61.08         a
# 3 22.6                159.79                        105.21         a
# 4 30.0                152.39                         75.35         a
# 5 32.5                139.11                         59.45         a
# 6 36.0                154.99                         59.03         a

# %%
head( df.ba )
# Out:
#   School       Average.daily.Attendance Percent.Attendance Pupil.Teacher.ratio
# 1 East Lake    225.3                    91.07              36.7
# 2 Milton       262.5                    93.48              31.3
# 3 Sylvan Hills 294.1                    92.43              33.6
# 4 Calhoun         NA                       NA              23.0
# 5 Jones        238.3                    90.38              27.9
# 6 Lee          381.1                    89.30              30.0

# %%
head( df.bf )
# Out:
#   School       Value  Metric
# 1 East Lake     61.91 Per-Pupil Cost
# 2 Milton        90.21 Per-Pupil Cost
# 3 Sylvan Hills  59.27 Per-Pupil Cost
# 4 Calhoun      108.57 Per-Pupil Cost
# 5 Jones         81.47 Per-Pupil Cost
# 6 Lee           73.64 Per-Pupil Cost

# %%
df.b <- left_join( df.ba, df.bf )
# Out:
# Joining, by = "School"

# %%
df.b <- df.b[1:40,]

# %%
df.b <- df.b %>%
    spread( Metric, Value )

# %%
df.b$district_cd <- 'b'

# %%
head( df.b )
# Out:
#   School       Average.daily.Attendance Percent.Attendance Pupil.Teacher.ratio
# 1 Calhoun         NA                       NA              23.0
# 2 Capitol View 268.9                    92.44              29.4
# 3 Connally     161.7                    92.01              29.4
# 4 Couch        422.1                    91.60              29.2
# 5 East Lake    225.3                    91.07              36.7
# 6 Fair         333.9                    88.39              27.6
#   Average Monthly Teacher Salary Per-Pupil Cost district_cd
# 1 161.79                         108.57         b
# 2 136.37                          70.00         b
# 3 106.86                          49.04         b
# 4 147.17                          71.51         b
# 5 106.74                          61.91         b
# 6 130.24                          75.14         b

# %%
names( df.b ) <- c( 'school_nm'
                   , 'attendance_daily_average_no'
                   , 'attendance_percent_no'
                   , 'pupil_teacher_ratio'
                  , 'teacher_monthly_avg_salary_no'
                  , 'per_pupil_cost'
                  , 'district_cd' )

# %%
df <- rbind( df.a, df.b )

# %%
df
# Out:
#    school_nm    attendance_daily_average_no attendance_percent_no
# 1  Adair         451.4                      90.77
# 2  Crew          440.6                      89.32
# 3  Davis         139.4                      86.51
# 4  Faith         427.3                      91.12
# 5  Formwalt      706.1                      89.46
# 6  Forrest      4312.0                      89.72
# 7  Georgia       464.2                      90.53
# 8  Goldsmith     227.7                      92.81
# 9  Gordon        551.4                      91.98
# 10 Grant Park    684.0                      86.47
# 11 Harris        585.1                      93.15
# 12 Home Park     402.0                      91.01
# 13 Howell        556.6                      90.88
# 14 Key           668.9                      90.47
# 15 Kingsbury    1065.4                      92.00
# 16 Kirkwood      641.1                      91.03
# 17 Lin           476.3                      92.05
# 18 Morningside   507.2                      90.47
# 19 Pryor         257.2                      89.87
# 20 Ragsdale      329.6                      94.72
# 21 Slaton        646.5                      90.70
# 22 Stanton       212.0                      93.22
# 23 West         3311.0                      90.78
# 24 Williams      295.8                      89.11
# 25 Calhoun          NA                         NA
# 26 Capitol View  268.9                      92.44
# 27 Connally      161.7                      92.01
# 28 Couch         422.1                      91.60
# 29 East Lake     225.3                      91.07
# 30 Fair          333.9                      88.39
# 31 Haygood       284.3                      89.01
# 32 Highland      498.3                      91.11
# 33 Inman Park    281.5                      87.51
# 34 Jones         238.3                      90.38
# 35 Lee           381.1                      89.30
# 36 Luckie        503.4                      88.19
# 37 Milton        262.5                      93.48
# 38 Moreland      685.3                      92.96
# 39 Peeples       511.0                      92.51
# 40 S.M. Inman       NA                         NA
# 41 Smillie       376.9                      92.26
# 42 Spring        354.7                      91.23
# 43 Sylvan Hills  294.1                      92.43
# 44 Whiteford     501.6                      90.38
#    pupil_teacher_ratio teacher_monthly_avg_salary_no per_pupil_cost district_cd
# 1  33.8                160.22                         66.90         a
# 2  36.3                146.24                         61.08         a
# 3  22.6                159.79                        105.21         a
# 4  30.0                152.39                         75.35         a
# 5  32.5                139.11                         59.45         a
# 6  36.0                154.99                         59.03         a
# 7  29.2                    NA                            NA         a
# 8  30.8                141.34                         71.76         a
# 9  31.9                153.19                         66.96         a
# 10 28.6                135.70                         73.26         a
# 11 29.2                148.77                         65.65         a
# 12 30.2                156.93                         65.97         a
# 13 33.5                154.95                         61.74         a
# 14 33.4                140.39                         58.80         a
# 15 30.2                140.24                         62.47         a
# 16 30.7                159.19                         66.44         a
# 17 35.0                151.84                         56.07         a
# 18 30.7                117.99                         58.25         a
# 19 30.4                146.75                         60.90         a
# 20 25.8                124.82                         80.12         a
# 21 30.7                160.13                         58.35         a
# 22 30.2                166.10                         73.27         a
# 23 28.2                146.60                         75.43         a
# 24 32.1                125.92                         49.76         a
# 25 23.0                161.79                        108.57         b
# 26 29.4                136.37                         70.00         b
# 27 29.4                106.86                         49.04         b
# 28 29.2                147.17                         71.51         b
# 29 36.7                106.74                         61.91         b
# 30 27.6                130.24                         75.14         b
# 31 27.0                157.38                         72.11         b
# 32 30.8                148.60                         64.58         b
# 33 26.9                147.59                         87.07         b
# 34 27.9                132.17                         81.47         b
# 35 30.0                136.21                         73.64         b
# 36 34.6                144.83                         60.48         b
# 37 31.3                165.13                         90.21         b
# 38 35.2                149.61                         54.10         b
# 39 35.2                151.36                         58.45         b
# 40 32.0                139.91                         58.27         b
# 41 31.2                146.85                         61.77         b
# 42 33.1                151.61                         67.60         b
# 43 33.6                116.53                         59.27         b
# 44 30.8                148.49                         64.54         b

# %% [markdown]
# ### Missing data

# %% [markdown]
# #### Need to predict salary and cost for Georgia
# Per pupil cost was the only variable in a linear model that was significant, and Gergia has a missing value for that as well, so will use average salary across district a.

# %%
mean( df[df$district_cd == 'a',]$teacher_monthly_avg_salary_no, na.rm = TRUE )
# Out:
# [1] 147.1126

# %%
df[df$school_nm == 'Georgia',]$teacher_monthly_avg_salary_no <- 141.11

# %%
summary( glm( per_pupil_cost
   ~ pupil_teacher_ratio
   + teacher_monthly_avg_salary_no
   , family = gaussian()
   , data = df ) )
# Out:
# Call:
# glm(formula = per_pupil_cost ~ pupil_teacher_ratio + teacher_monthly_avg_salary_no,
#     family = gaussian(), data = df)
#
# Deviance Residuals:
#      Min        1Q    Median        3Q       Max
# -13.9610   -5.0221   -0.6164    3.7648   19.5516
#
# Coefficients:
#                                Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   120.05254   17.30636   6.937 2.30e-08 ***
# pupil_teacher_ratio            -2.82376    0.37152  -7.600 2.77e-09 ***
# teacher_monthly_avg_salary_no   0.24300    0.08225   2.955  0.00523 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 58.97481)
#
#     Null deviance: 6565.4  on 42  degrees of freedom
# Residual deviance: 2359.0  on 40  degrees of freedom
#   (1 observation deleted due to missingness)
# AIC: 302.23
#
# Number of Fisher Scoring iterations: 2

# %%
( -2.82376 * 29.2 ) + ( 0.243 * 141.11 ) + 120.05254
# Out:
# [1] 71.88848

# %%
df[df$school_nm == 'Georgia',]$per_pupil_cost <- 71.89

# %% [markdown]
# #### Need to predict attendance daily average number oand percent for S.M. Inman and Calhoun

# %%
ggplot( df, aes( x = attendance_daily_average_no ) ) +
    geom_density()
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (stat_density).”
# plot without title

# %%
fit.att <- glm( attendance_daily_average_no
            ~ per_pupil_cost
            , family = gaussian()
            , data = df[df$attendance_daily_average_no < 2000,] )

# %%
t( coef( fit.att )  )
# Out:
#      (Intercept) per_pupil_cost
# [1,] 869.3438    -6.482003

# %%
df[df$school_nm == 'Calhoun',]$attendance_daily_average_no <- ( -6.482003 * 108.57 ) + 869.3438

# %%
df[df$school_nm == 'S.M. Inman',]$attendance_daily_average_no <- ( -6.482003 * 58.27 ) + 869.3438

# %%
df[40,]$attendance_percent_no <- 91.64

# %% [markdown]
# No variable significant in a linear model, so using average

# %%
mean( df$attendance_percent_no, na.rm = TRUE )
# Out:
# [1] 90.83837

# %%
df[is.na( df$attendance_percent_no),]$attendance_percent_no <- mean( df$attendance_percent_no, na.rm = TRUE )

# %% [markdown]
# ### Outliers
# Forrest, Kingsbury, and West have outlier attendance_daily_average_no values.
# Forrest and West seem to be simple errors. Kingsbury is less clear

# %%
ggplot( df, aes( y = attendance_daily_average_no, x = district_cd ) ) +
    geom_boxplot()
# Out:
# plot without title

# %%
df
# Out:
#    school_nm    attendance_daily_average_no attendance_percent_no
# 1  Adair         451.4000                   90.77000
# 2  Crew          440.6000                   89.32000
# 3  Davis         139.4000                   86.51000
# 4  Faith         427.3000                   91.12000
# 5  Formwalt      706.1000                   89.46000
# 6  Forrest      4312.0000                   89.72000
# 7  Georgia       464.2000                   90.53000
# 8  Goldsmith     227.7000                   92.81000
# 9  Gordon        551.4000                   91.98000
# 10 Grant Park    684.0000                   86.47000
# 11 Harris        585.1000                   93.15000
# 12 Home Park     402.0000                   91.01000
# 13 Howell        556.6000                   90.88000
# 14 Key           668.9000                   90.47000
# 15 Kingsbury    1065.4000                   92.00000
# 16 Kirkwood      641.1000                   91.03000
# 17 Lin           476.3000                   92.05000
# 18 Morningside   507.2000                   90.47000
# 19 Pryor         257.2000                   89.87000
# 20 Ragsdale      329.6000                   94.72000
# 21 Slaton        646.5000                   90.70000
# 22 Stanton       212.0000                   93.22000
# 23 West         3311.0000                   90.78000
# 24 Williams      295.8000                   89.11000
# 25 Calhoun       165.5927                   90.83837
# 26 Capitol View  268.9000                   92.44000
# 27 Connally      161.7000                   92.01000
# 28 Couch         422.1000                   91.60000
# 29 East Lake     225.3000                   91.07000
# 30 Fair          333.9000                   88.39000
# 31 Haygood       284.3000                   89.01000
# 32 Highland      498.3000                   91.11000
# 33 Inman Park    281.5000                   87.51000
# 34 Jones         238.3000                   90.38000
# 35 Lee           381.1000                   89.30000
# 36 Luckie        503.4000                   88.19000
# 37 Milton        262.5000                   93.48000
# 38 Moreland      685.3000                   92.96000
# 39 Peeples       511.0000                   92.51000
# 40 S.M. Inman    491.6375                   91.64000
# 41 Smillie       376.9000                   92.26000
# 42 Spring        354.7000                   91.23000
# 43 Sylvan Hills  294.1000                   92.43000
# 44 Whiteford     501.6000                   90.38000
#    pupil_teacher_ratio teacher_monthly_avg_salary_no per_pupil_cost district_cd
# 1  33.8                160.22                         66.90         a
# 2  36.3                146.24                         61.08         a
# 3  22.6                159.79                        105.21         a
# 4  30.0                152.39                         75.35         a
# 5  32.5                139.11                         59.45         a
# 6  36.0                154.99                         59.03         a
# 7  29.2                141.11                         71.89         a
# 8  30.8                141.34                         71.76         a
# 9  31.9                153.19                         66.96         a
# 10 28.6                135.70                         73.26         a
# 11 29.2                148.77                         65.65         a
# 12 30.2                156.93                         65.97         a
# 13 33.5                154.95                         61.74         a
# 14 33.4                140.39                         58.80         a
# 15 30.2                140.24                         62.47         a
# 16 30.7                159.19                         66.44         a
# 17 35.0                151.84                         56.07         a
# 18 30.7                117.99                         58.25         a
# 19 30.4                146.75                         60.90         a
# 20 25.8                124.82                         80.12         a
# 21 30.7                160.13                         58.35         a
# 22 30.2                166.10                         73.27         a
# 23 28.2                146.60                         75.43         a
# 24 32.1                125.92                         49.76         a
# 25 23.0                161.79                        108.57         b
# 26 29.4                136.37                         70.00         b
# 27 29.4                106.86                         49.04         b
# 28 29.2                147.17                         71.51         b
# 29 36.7                106.74                         61.91         b
# 30 27.6                130.24                         75.14         b
# 31 27.0                157.38                         72.11         b
# 32 30.8                148.60                         64.58         b
# 33 26.9                147.59                         87.07         b
# 34 27.9                132.17                         81.47         b
# 35 30.0                136.21                         73.64         b
# 36 34.6                144.83                         60.48         b
# 37 31.3                165.13                         90.21         b
# 38 35.2                149.61                         54.10         b
# 39 35.2                151.36                         58.45         b
# 40 32.0                139.91                         58.27         b
# 41 31.2                146.85                         61.77         b
# 42 33.1                151.61                         67.60         b
# 43 33.6                116.53                         59.27         b
# 44 30.8                148.49                         64.54         b

# %%
df[df$school_nm == 'Forrest',]$attendance_daily_average_no <- 432

# %%
df[df$school_nm == 'West',]$attendance_daily_average_no <- 311

# %%
ggplot( df, aes( y = attendance_percent_no, x = district_cd ) ) +
    geom_boxplot()
# Out:
# plot without title

# %%
ggplot( df, aes( y = pupil_teacher_ratio, x = district_cd ) ) +
    geom_boxplot()
# Out:
# plot without title

# %%
ggplot( df, aes( y = teacher_monthly_avg_salary_no, x = district_cd ) ) +
    geom_boxplot()
# Out:
# plot without title

# %%
ggplot( df, aes( y = per_pupil_cost, x = district_cd ) ) +
    geom_boxplot()
# Out:
# plot without title
