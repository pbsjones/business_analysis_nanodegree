# %% [markdown]
# # Project: Section 4 | Classification | Creditworthiness

# %% [markdown]
# ## Course: Business Analyst Nanodegree
# ## Student: Peter Jones
# ## Date: 2018.04.09

# %% [markdown]
# ----

# %% [markdown]
# ## Step 1: Business understanding

# %% [markdown]
# ### What decision needs to be made?
# The decision to be made here is to determine how many creditworthy customers exist in a list of new loan applications.

# %% [markdown]
# ### What data is needed to make this decision?
# To build a model to assist in making this decision, data is needed on as many past loan approvals as possible, with as mmuch data on the customers as is feasible to collect and the outcome of whether the customer ended up being creditworthy or not.

# %% [markdown]
# ### What kind of model (Continuous, Binary, Non-Binary, Time-Series) do we need to use to help make these decisions?
# The outcome variable for these data is a binary value of creditworthy or not, so we would create binary models to help make this decision.

# %% [markdown]
# ## Step 2: Building the training set

# %% [markdown]
# ### Libraries

# %%
library( tidyverse )
require( PerformanceAnalytics )
library( caret )
library( Amelia )
library(randomForest)
library( rpart )
library( rpart.plot )
library( reprtree )
library( reshape2 )
library( gbm )
library( pROC )

options(jupyter.plot_mimetypes = c("text/plain", "image/png" ))
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.3.4     ✔ dplyr   0.7.4
# ✔ tidyr   0.7.2     ✔ stringr 1.2.0
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Loading required package: PerformanceAnalytics
# Loading required package: xts
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# Attaching package: ‘xts’
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, last
#
#
# Attaching package: ‘PerformanceAnalytics’
#
# The following object is masked from ‘package:graphics’:
#
#     legend
#
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift
#
# Loading required package: Rcpp
# ##
# ## Amelia II: Multiple Imputation
# ## (Version 1.7.4, built: 2015-12-05)
# ## Copyright (C) 2005-2018 James Honaker, Gary King and Matthew Blackwell
# ## Refer to http://gking.harvard.edu/amelia/ for more information
# ##
# Warning message:
# “package ‘randomForest’ was built under R version 3.4.4”randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
# Loading required package: tree
# Warning message:
# “package ‘tree’ was built under R version 3.4.4”Loading required package: plotrix
#
# Attaching package: ‘reshape2’
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
# Loading required package: survival
#
# Attaching package: ‘survival’
#
# The following object is masked from ‘package:caret’:
#
#     cluster
#
# Loading required package: splines
# Loading required package: parallel
# Loaded gbm 2.1.3
# Type 'citation("pROC")' for a citation.
#
# Attaching package: ‘pROC’
#
# The following objects are masked from ‘package:stats’:
#
#     cov, smooth, var

# %%
df.train.raw <- readxl::read_excel( '../data/classification/credit-data-training.xlsx' )
df.test.raw <- readxl::read_excel( '../data/classification/customers-to-score.xlsx')

# %%
names( df.train.raw ) <- c( "application_result_txt"
                           , "acct_balance_txt"
                           , "months_of_credit_no"
                           , "prev_payment_status_txt"
                           , "purpose_txt"
                           , "credit_amt_no"
                           , "savings_stocks_val_no"
                           , "curr_employment_length_no"
                           , "installment_perc_no"
                           , "guarantors_txt"
                           , "curr_address_dur_no"
                           , "most_val_asset_cd"
                           , "age_no"
                           , "concurrent_credits_txt"
                           , "apartment_type_txt"
                           , "credits_at_bank_no"
                           , "occupation_txt"
                           , "dependents_no"
                           , "telephone_txt"
                           , "foreign_worker_flg" )

# %%
df.train.raw <- transform(  df.train.raw
                          , application_result_txt = factor( application_result_txt ) 
                          , acct_balance_txt = factor( acct_balance_txt )
                          , months_of_credit_no = months_of_credit_no
                          , prev_payment_status_txt = factor( prev_payment_status_txt )
                          , purpose_txt = factor( purpose_txt )
                          , credit_amt_no = credit_amt_no
                          , savings_stocks_val_no = factor( savings_stocks_val_no )
                          , curr_employment_length_no = factor( curr_employment_length_no )
                          , installment_perc_no = installment_perc_no
                          , guarantors_txt = factor( guarantors_txt )
                          , curr_address_dur_no = curr_address_dur_no
                          , most_val_asset_cd = factor( most_val_asset_cd )
                          , age_no = age_no
                          , concurrent_credits_txt = factor( concurrent_credits_txt )
                          , apartment_type_txt = factor( apartment_type_txt )
                          , credits_at_bank_no = factor( credits_at_bank_no )
                          , occupation_txt = factor( occupation_txt )
                          , dependents_no = dependents_no
                          , telephone_txt = factor( telephone_txt )
                          , foreign_worker_flg = factor( foreign_worker_flg )
                         )

# %%
facvar <- c( "application_result_txt"
           , "acct_balance_txt"
           , "prev_payment_status_txt"
           , "purpose_txt"
           , "savings_stocks_val_no"
           , "curr_employment_length_no"
           , "guarantors_txt"
           , "most_val_asset_cd"
           , "concurrent_credits_txt"
           , "apartment_type_txt"
           , "credits_at_bank_no"
           , "occupation_txt"
           , "telephone_txt"
           , "foreign_worker_flg" )

# %%
convar <- c( "months_of_credit_no"
           , "credit_amt_no"
           , "installment_perc_no"
           , "curr_address_dur_no"
           , "age_no"
           , "dependents_no" )

# %%
names( df.test.raw ) <- c(   "acct_balance_txt"
                           , "months_of_credit_no"
                           , "prev_payment_status_txt"
                           , "purpose_txt"
                           , "credit_amt_no"
                           , "savings_stocks_val_no"
                           , "curr_employment_length_no"
                           , "installment_perc_no"
                           , "guarantors_txt"
                           , "curr_address_dur_no"
                           , "most_val_asset_cd"
                           , "age_no"
                           , "concurrent_credits_txt"
                           , "apartment_type_txt"
                           , "credits_at_bank_no"
                           , "occupation_txt"
                           , "dependents_no"
                           , "telephone_txt"
                           , "foreign_worker_flg" )

# %%
df.test.raw <- transform(  df.test.raw
                          , acct_balance_txt = factor( acct_balance_txt )
                          , months_of_credit_no = months_of_credit_no
                          , prev_payment_status_txt = factor( prev_payment_status_txt )
                          , purpose_txt = factor( purpose_txt )
                          , credit_amt_no = credit_amt_no
                          , savings_stocks_val_no = factor( savings_stocks_val_no )
                          , curr_employment_length_no = factor( curr_employment_length_no )
                          , installment_perc_no = installment_perc_no
                          , guarantors_txt = factor( guarantors_txt )
                          , curr_address_dur_no = curr_address_dur_no
                          , most_val_asset_cd = factor( most_val_asset_cd )
                          , age_no = age_no
                          , concurrent_credits_txt = factor( concurrent_credits_txt )
                          , apartment_type_txt = factor( apartment_type_txt )
                          , credits_at_bank_no = factor( credits_at_bank_no )
                          , occupation_txt = factor( occupation_txt )
                          , dependents_no = dependents_no
                          , telephone_txt = factor( telephone_txt )
                          , foreign_worker_flg = factor( foreign_worker_flg )
                         )

# %%
ggplot( df.train.raw, aes( x = application_result_txt ) ) +
    geom_bar( ) +
    theme_classic()
# Out:
# plot without title

# %% [markdown]
# ### Are any of your numerical data fields highly-correlated with each other?

# %%
chart.Correlation( df.train.raw[,convar])
# Out:
# Plot with title “”

# %% [markdown]
# #### No variables reach the .7 threshold of being highly correlated, so all retained.

# %% [markdown]
# ### Are there any missing data for each of the data fields?

# %%
missmap( df.train.raw )
# Out:
# Plot with title “Missingness Map”

# %% [markdown]
# #### Removing address_dur_no due to missingness.

# %%
df.train.raw <- select( df.train.raw, -curr_address_dur_no )

# %% [markdown]
# #### Impute missing values for age_no as median

# %%
df.train.raw[is.na( df.train.raw$age_no ),]$age_no <- median( df.train.raw$age_no, na.rm = TRUE )

# %% [markdown]
# ### Are there only a few values in a subset of your data field? Does the data field look very uniform (there is only one value for the entire field?).

# %%
fac.check <- melt( df.train.raw[,facvar], 1 )
# Out:
# Warning message:
# “attributes are not identical across measure variables; they will be dropped”

# %%
ggplot( fac.check, aes( x = value ) ) +
    geom_bar() +
    facet_wrap( ~variable, scales = "free_x" ) +
    theme_classic()
# Out:
# plot without title

# %% [markdown]
# Removing occupation_txt, concurrent_credits_txt, guarantors_txt, and foreign_worker_flg due to low variablility. Levels in purpose_txt don't match between training data and new data, so removing.

# %%
df.train.raw <- df.train.raw %>%
    select( -occupation_txt ) %>%
    select( -concurrent_credits_txt ) %>%
    select( -guarantors_txt ) %>%
    select( -foreign_worker_flg ) %>%
    select( -purpose_txt )

# %% [markdown]
# ### Checking age value against the course information

# %%
round( mean( df.train.raw$age_no, na.rm = TRUE ) )
# Out:
# [1] 36

# %% [markdown]
# #### Data looks clean, though I have 15 columns where the course information says to have 13.

# %% [markdown]
# ## Step 3: Train classification models

# %% [markdown]
# ### Create training and validation sets

# %%
set.seed( 1 )

# %%
train <- createDataPartition( df.train.raw$application_result_txt
                             , times = 1
                             , p = 0.7
                             , list = FALSE )

# %%
df.train <- df.train.raw[train,]

# %%
df.val <- df.train.raw[-train,]

# %% [markdown]
# ### Logistic regression

# %%
fit.glm.full <- glm( application_result_txt
              ~ .
              , data = df.train
              , family = binomial )

# %%
summary( fit.glm.full )
# Out:
# Call:
# glm(formula = application_result_txt ~ ., family = binomial,
#     data = df.train)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.7164  -0.7510  -0.4923   0.7727   2.3458
#
# Coefficients:
#                                        Estimate Std. Error z value Pr(>|z|)
# (Intercept)                          -3.880e+00  1.028e+00  -3.773 0.000161 ***
# acct_balance_txtSome Balance         -1.346e+00  3.145e-01  -4.281 1.86e-05 ***
# months_of_credit_no                   7.736e-03  1.347e-02   0.574 0.565678
# prev_payment_status_txtPaid Up        3.889e-01  3.934e-01   0.989 0.322821
# prev_payment_status_txtSome Problems  1.508e+00  5.361e-01   2.814 0.004899 **
# credit_amt_no                         1.227e-04  6.838e-05   1.795 0.072703 .
# savings_stocks_val_no£100-£1000       2.475e-01  5.375e-01   0.460 0.645175
# savings_stocks_val_noNone             6.956e-01  4.827e-01   1.441 0.149532
# curr_employment_length_no1-4 yrs     -5.567e-01  3.652e-01  -1.524 0.127407
# curr_employment_length_no4-7 yrs     -9.582e-02  3.720e-01  -0.258 0.796711
# installment_perc_no                   3.888e-01  1.424e-01   2.730 0.006341 **
# most_val_asset_cd2                    6.661e-01  4.072e-01   1.636 0.101931
# most_val_asset_cd3                    5.355e-01  3.825e-01   1.400 0.161469
# most_val_asset_cd4                    1.362e+00  6.185e-01   2.203 0.027607 *
# age_no                               -8.312e-03  1.379e-02  -0.603 0.546743
# apartment_type_txt2                   1.437e-01  3.665e-01   0.392 0.694905
# apartment_type_txt3                  -3.614e-01  7.049e-01  -0.513 0.608119
# credits_at_bank_noMore than 1         2.284e-01  3.927e-01   0.582 0.560789
# dependents_no                         5.138e-01  3.995e-01   1.286 0.198433
# telephone_txt2                       -1.038e-01  3.002e-01  -0.346 0.729531
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 419.46  on 350  degrees of freedom
# Residual deviance: 344.23  on 331  degrees of freedom
# AIC: 384.23
#
# Number of Fisher Scoring iterations: 4

# %%
fit.glm.red <- glm( application_result_txt
              ~ acct_balance_txt
              + prev_payment_status_txt
                + credit_amt_no
                + installment_perc_no
                + most_val_asset_cd
              , data = df.train
              , family = binomial )

# %%
summary( fit.glm.red )
# Out:
# Call:
# glm(formula = application_result_txt ~ acct_balance_txt + prev_payment_status_txt +
#     credit_amt_no + installment_perc_no + most_val_asset_cd,
#     family = binomial, data = df.train)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.8697  -0.7620  -0.5222   0.7995   2.3407
#
# Coefficients:
#                                        Estimate Std. Error z value Pr(>|z|)
# (Intercept)                          -2.743e+00  5.991e-01  -4.579 4.68e-06 ***
# acct_balance_txtSome Balance         -1.385e+00  2.923e-01  -4.738 2.16e-06 ***
# prev_payment_status_txtPaid Up        2.682e-01  2.886e-01   0.929  0.35268
# prev_payment_status_txtSome Problems  1.442e+00  5.091e-01   2.833  0.00461 **
# credit_amt_no                         1.299e-04  5.257e-05   2.471  0.01347 *
# installment_perc_no                   3.635e-01  1.341e-01   2.710  0.00673 **
# most_val_asset_cd2                    6.501e-01  3.958e-01   1.643  0.10048
# most_val_asset_cd3                    5.452e-01  3.656e-01   1.491  0.13594
# most_val_asset_cd4                    9.770e-01  4.425e-01   2.208  0.02726 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 419.46  on 350  degrees of freedom
# Residual deviance: 353.87  on 342  degrees of freedom
# AIC: 371.87
#
# Number of Fisher Scoring iterations: 4

# %%
df.val$pred <- predict( fit.glm.red
                       , df.val
                       , type = 'response' )

# %%
df.val<- within( df.val, {
    pred[pred >= 0.5] = 'Creditworthy'
    pred[pred< 0.5] = 'Non-Creditworthy'
})
df.val$pred <- factor( df.val$pred )

# %%
confusionMatrix( df.val$application_result_txt
                , df.val$pred )
# Out:
# Confusion Matrix and Statistics
#
#                   Reference
# Prediction         Creditworthy Non-Creditworthy
#   Creditworthy                5              102
#   Non-Creditworthy           13               29
#
#                Accuracy : 0.2282
#                  95% CI : (0.1635, 0.304)
#     No Information Rate : 0.8792
#     P-Value [Acc > NIR] : 1
#
#                   Kappa : -0.1599
#  Mcnemar's Test P-Value : 2.286e-16
#
#             Sensitivity : 0.27778
#             Specificity : 0.22137
#          Pos Pred Value : 0.04673
#          Neg Pred Value : 0.69048
#              Prevalence : 0.12081
#          Detection Rate : 0.03356
#    Detection Prevalence : 0.71812
#       Balanced Accuracy : 0.24958
#
#        'Positive' Class : Creditworthy

# %% [markdown]
# ### Decision tree model

# %%
fit.dt <- rpart( application_result_txt 
     ~ .
     , data = df.train )

# %%
rpart.plot( fit.dt )
# Out:
# plot without title

# %%
df.val$pred <- predict( fit.dt
       , df.val
       , type = 'class')

# %%
confusionMatrix( df.val$application_result_txt
               , df.val$pred )
# Out:
# Confusion Matrix and Statistics
#
#                   Reference
# Prediction         Creditworthy Non-Creditworthy
#   Creditworthy               97               10
#   Non-Creditworthy           30               12
#
#                Accuracy : 0.7315
#                  95% CI : (0.6529, 0.8008)
#     No Information Rate : 0.8523
#     P-Value [Acc > NIR] : 0.999958
#
#                   Kappa : 0.2248
#  Mcnemar's Test P-Value : 0.002663
#
#             Sensitivity : 0.7638
#             Specificity : 0.5455
#          Pos Pred Value : 0.9065
#          Neg Pred Value : 0.2857
#              Prevalence : 0.8523
#          Detection Rate : 0.6510
#    Detection Prevalence : 0.7181
#       Balanced Accuracy : 0.6546
#
#        'Positive' Class : Creditworthy

# %% [markdown]
# ### Forest model

# %%
fit.rf <- randomForest( application_result_txt
            ~ .
            , data = df.train )

# %%
plot( fit.rf )
# Out:
# Plot with title “fit.rf”

# %%
df.val$pred <- predict( fit.rf
       , df.val )

# %%
confusionMatrix( df.val$application_result_txt
               , df.val$pred )
# Out:
# Confusion Matrix and Statistics
#
#                   Reference
# Prediction         Creditworthy Non-Creditworthy
#   Creditworthy              101                6
#   Non-Creditworthy           27               15
#
#                Accuracy : 0.7785
#                  95% CI : (0.7033, 0.8424)
#     No Information Rate : 0.8591
#     P-Value [Acc > NIR] : 0.9972253
#
#                   Kappa : 0.355
#  Mcnemar's Test P-Value : 0.0004985
#
#             Sensitivity : 0.7891
#             Specificity : 0.7143
#          Pos Pred Value : 0.9439
#          Neg Pred Value : 0.3571
#              Prevalence : 0.8591
#          Detection Rate : 0.6779
#    Detection Prevalence : 0.7181
#       Balanced Accuracy : 0.7517
#
#        'Positive' Class : Creditworthy

# %%
varImpPlot( fit.rf )
# Out:
# Plot with title “fit.rf”

# %% [markdown]
# ### Boosted tree model

# %%
fit.bm <- gbm( as.numeric( application_result_txt ) - 1
             ~ .
             , data = df.train
             , distribution = 'bernoulli'
             , n.trees = 70
             , interaction.depth = 5
             , shrinkage = 0.3
             , bag.fraction = 0.5
             , train.fraction = 1.0
             , n.cores = NULL)  #will use all cores by default

# %%
df.val$pred <- predict.gbm( fit.bm
       , df.val
       , n.trees = 70
       , type = 'response' )

# %%
df.val$bm.pred <- as.numeric( df.val$pred >= 0.4 )

# %%
df.val <- within( df.val, {
    pred[bm.pred == 1] = 'Non-creditworthy'
    pred[bm.pred == 0] = 'Creditworthy'
})
df.val$pred <- factor( df.val$pred )

# %%
summary( fit.bm )
# Out:
#                           var                       rel.inf
# credit_amt_no             credit_amt_no             30.8389332
# age_no                    age_no                    14.6515168
# months_of_credit_no       months_of_credit_no       11.0308405
# most_val_asset_cd         most_val_asset_cd          9.1250088
# prev_payment_status_txt   prev_payment_status_txt    7.6065144
# acct_balance_txt          acct_balance_txt           5.4653478
# savings_stocks_val_no     savings_stocks_val_no      4.8688083
# installment_perc_no       installment_perc_no        4.4362671
# apartment_type_txt        apartment_type_txt         4.1783964
# curr_employment_length_no curr_employment_length_no  2.9084242
# telephone_txt             telephone_txt              2.7173833
# credits_at_bank_no        credits_at_bank_no         1.7555462
# dependents_no             dependents_no              0.4170128
# plot without title

# %%
cm <- cbind(df.val$application_result_txt, df.val$pred)

# %%
confusionMatrix( cm[,1], cm[,2] )
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction  1  2
#          1 87 20
#          2 22 20
#
#                Accuracy : 0.7181
#                  95% CI : (0.6387, 0.7887)
#     No Information Rate : 0.7315
#     P-Value [Acc > NIR] : 0.6820
#
#                   Kappa : 0.2935
#  Mcnemar's Test P-Value : 0.8774
#
#             Sensitivity : 0.7982
#             Specificity : 0.5000
#          Pos Pred Value : 0.8131
#          Neg Pred Value : 0.4762
#              Prevalence : 0.7315
#          Detection Rate : 0.5839
#    Detection Prevalence : 0.7181
#       Balanced Accuracy : 0.6491
#
#        'Positive' Class : 1

# %% [markdown]
# ### Compare the accuracy of the four models

# %%
ac.log <- c( 'Logistic regression', 0.228 )
ac.dt <- c( 'Decision tree', 0.7315 )
ac.rf <- c( 'Random forest', 0.7785 )
ac.bm <- c( 'Gradient boosted model', 0.7181 )

# %%
ac.tbl <- rbind( ac.log
     , ac.dt
     , ac.rf
     , ac.bm )

# %%
ac.tbl
# Out:
#        [,1]                   [,2]
# ac.log Logistic regression    0.228
# ac.dt  Decision tree          0.7315
# ac.rf  Random forest          0.7785
# ac.bm  Gradient boosted model 0.7181

# %% [markdown]
# The random forest model appears to be the most accurate from a comparison of the confusion matrices.

# %% [markdown]
# ### Which predictor variables are significant or the most important?

# %% [markdown]
# For the logistic regression model, the following variables were significant:
# - Account balance
# - Previous payment status
# - Purpose
# - Credit amount
# - Installment percent
# - Most valuable asset
#
# For the decision tree model, the following variables were important:
# - Account balance
# - Months of credit
# - Installment percent
# - Previous payment status
#
# For the random forest, the following variables were important:
# - Credit amount
# - Months of credit
# - Age
#
# For the boosted model, the following variables were important:
# - Credit amount
# - Months of credit
# - Age

# %% [markdown]
# ### What was the overall percent accuracy? Show the confusion matrix. Are there any biases seen in the model’s predictions?
# For all models, see the confusion matrices above.
# - For the logistic regression model, overall accuracy was 23%. There seems to be a bias toward the non-creditworthy prediction here.
# - For the decision tree model, overall accuracy was 73%. From the confusion matrix, it looks like there is a bias toward accurately predicting the creditworthy customers.
# - For the random forest model, overall accuracy was 78%. From the confusion matrix, it looks like there is a bias toward accurately predicting the creditworthy customers.
# - For the gradient boosted model, the overall accuracy was 72%. From the confusion matrix, it looks like there is a bias toward accurately predicting the creditworthy customers.

# %% [markdown]
# ## Report

# %% [markdown]
# Random forest has the highest accuracy at 77%. I will use this model to score the new customers.

# %% [markdown]
# ### Score the new data

# %%
df.test.raw <- df.test.raw %>%
    select( -curr_address_dur_no ) %>%
    select( -occupation_txt ) %>%
    select( -concurrent_credits_txt ) %>%
    select( -guarantors_txt ) %>%
    select( -foreign_worker_flg ) %>%
    select( -purpose_txt )

# %%
df.test.raw$pred <- predict( fit.rf, newdata = df.test.raw )

# %%
table( df.test.raw$pred )
# Out:
#     Creditworthy Non-Creditworthy
#              436               64

# %% [markdown]
# ## Write-up

# %% [markdown]
# To come up with this prediction, I split the training data into train and validation sets and ran four classification models on the train data. I then ran a comparison of all models on validation sets with an emphasis on accuracy (per requirements), and scored new customers with the most accurate model, the random forest.
#
# This model had a 78% accuracy against the validation set.
# Creditowrthy accuracy was 79%. Non-creditworthy accuracy was 71%.

# %%
pred.prob <- predict(fit.rf, df.val, type="prob")

# %%
df.val <- cbind( df.val, pred.prob )

# %%
roc.rf <- roc(df.val$application_result_txt, df.val$Creditworthy )

# %%
plot(roc.rf, print.thres="best", print.thres.best.method="closest.topleft")
# Out:
# plot without title

# %% [markdown]
# ## Conclusion
# I predict that 436 new customers will be deemed creditworthy.
