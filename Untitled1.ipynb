# %%
library( forecast )
# Out:
# Warning message:
# “package ‘forecast’ was built under R version 3.4.4”

# %%
tsdisplay( nottem )
# Out:
# Plot with title “”

# %%
plot( forecast( arima( nottem, order = c(1,1,0)) ) )
# Out:
# Plot with title “Forecasts from ARIMA(1,1,0)”
